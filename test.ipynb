# %%
import numpy as np
import joblib

# %%
rf_model = joblib.load('random_forest_surrogate_model.joblib')

# %%
k0 = 0
k1 = 90000
damping = 0.30
velocity = 10

# %%
input_data = np.array([[k0, k1, damping, velocity]])
predicted_output = rf_model.predict(input_data)
print(predicted_output)
# Out:
# [0.00244606]
# C:\Users\pasch\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
